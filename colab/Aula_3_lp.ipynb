# %% [markdown]
# <a href="https://colab.research.google.com/github/ClementeRamom777/lp-uninter-colab/blob/main/colab/Aula_3_lp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Exercícios pdf texto***

# %% [markdown]
# **Condicional simples:**

# %%
#Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))
if (x > y):
  print('O primeiro valor é maior que o segundo')
# Out:
# Digite um valor inteiro: 50
# Digite um segundo valor inteiro: 30
# O primeiro valor é maior que o segundo

# %%
#Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))
if (x > y):
  print('O primeiro valor é maior que o segundo!')
if (x < y):
  print('O segundo valor é maior que o segundo!')
# Out:
# Digite um valor inteiro: 6
# Digite um segundo valor inteiro: 6

# %%
#Implementando mais um "if" comparando os números com o sinal de igualdade, e imprimindo a mensagem 'Os números são iguais!'
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))
if (x > y):
  print('O primeiro valor é maior que o segundo!')
if (x < y):
  print('O segundo valor é maior que o primeiro!')
if (x == y):
  print('Os números são iguais!')
# Out:
# Digite um valor inteiro: 6
# Digite um segundo valor inteiro: 7
# O segundo valor é maior que o segundo!

# %% [markdown]
# **Condicional composta:**

# %%
#Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))
if (x > y):
  print('O primeiro valor é maior que o segundo')
else:
  print('O segundo valor é maior que o primeiro')
# Out:
# Digite um valor inteiro: 8
# Digite um segundo valor inteiro: 6
# O primeiro valor é maior que o segundo

# %%
#Lê dois valores inteiros e compara ambos
x = int(input('Digite um valor inteiro: '))
y = int(input('Digite um segundo valor inteiro: '))
if (x > y):
  print('O primeiro valor é maior que o segundo')
elif (x == y):
 print('Valores iguais')
else:
  print('O segundo valor é maior que o primeiro')
# Out:
# Digite um valor inteiro: 8
# Digite um segundo valor inteiro: 8
# Valores iguais

# %%
#par ou ímpar
x = int(input('Digite um valor inteiro: '))
if (x % 2 == 0) :
  print('O número é par')
else:
  print('O número é ímpar!')
# Out:
# Digite um valor inteiro: 89
# O número é ímpar!

# %%
# par ou ímpar
x = int(input('Digite um valor inteiro: '))
if (x % 2 == 0):
 print('O número é par!')
if (x % 2 == 1):
 print('O número é ímpar!')

# %%
# par ou ímpar e múltiplo de 7
x = int(input('Digite um valor inteiro: '))
if (x % 2 == 0):
 print('O número é par!')
else:
 print('O número é ímpar!')
if (x % 7 == 0):
 print('Múltiplo de 7!')
else:
 print('Não é múltiplo de 7!')

# %%
ano_nasc = int(input('Qual seu ano de nascimento?'))
ano_atual = int(input('Em que anos estamos?'))
idade = ano_atual - ano_nasc
print(f'Você tem {idade} anos de idade.')
if (idade >= 18):
 print('Você é de maior. Já pode tirar a carteira de motorista!')
# Out:
# Qual seu ano de nascimento?2000
# Em que anos estamos?2026
# Você tem 26 anos de idade.
# Você é de maior. Já pode tirar a carteira de motorista!

# %%
salario = float(input('Qual seu salário? '))
ano_admissao = int(input('Qual seu ano de admissão na empresa? '))
ano_atual = int(input('Em que ano estamos? '))
tempo = ano_atual - ano_admissao
if (tempo > 5):
  bonus = salario * 0.2
else:
  bonus = salario * 0.1
print(f'Você tem {tempo} anos dentro desta empresa.')
print(f'Seu Salário é de {salario}.')
print(f'E sua bonificação é de {bonus}.')
print(f'Salário final {bonus + salario}.')
# Out:
# Qual seu salário? 6000
# Qual seu ano de admissão na empresa? 2024
# Em que ano estamos? 2030
# Você tem 6 anos dentro desta empresa.
# Seu Salário é de 6000.0.
# E sua bonificação é de 1200.0.
# Salário final 7200.0.

# %%
# not
x = False
y = True
print(not y)
print(not x)
# Out:
# False
# True

# %%
# and
x = False
y = True
print(x and y)
# Out:
# False

# %%
# or
x = True
y = False
print(x or y)
# Out:
# True

# %%
x = 10
y = 1
res = not x > y
print(res)
# Out:
# False

# %%
x = 10
y = 1
z = 5.5
res = (x > y) and (z == y)
print(res)
# Out:
# False

# %%
x = 10
y = 1
z = 5.5
res = x > y or not z == y and y != y + z / x
print(res)
# Out:
# True

# %% [markdown]
# **Exercícios**

# %%
# Exercícios 3.3.1
m1 = float(input('Digite a nota da 1º matéria: '))
m2 = float(input('Digite a nota da 2º matéria: '))
m3 = float(input('Digite a nota da 3º matéria: '))
if m1 >= 7 and m2 >= 7 and m3 >= 7:
  print('O aluno está aprovado de ano!');
else:
  print('O aluno não passou de ano!')
# Out:
# Digite a nota da 1º matéria: 10
# Digite a nota da 2º matéria: 10
# Digite a nota da 3º matéria: 10
# O aluno está aprovado de ano!

# %%
# Exercícios 3.3.2
x = int(input('Digite um valor qualquer inteiro: '))
if x >= 1 and x <=100 or x >= -100 and x <= -1:
  print('Um dos critérios foi atingido.')
# Out:
# Digite um valor qualquer inteiro: 6
# Um dos critérios foi atingido.

# %% [markdown]
# **TEMA 4 - CONDICIONAIS ANINHADAS**

# %%
salario = float(input('Qual seu salário? '))
ano_admissao = int(input('Qual seu ano de admissão na empresa? '))
ano_atual = int(input('Em que ano estamos? '))
tempo = ano_atual - ano_admissao
if (tempo > 10):
  bonus = salario * 0.3
else:
  if (tempo > 5):
    bonus = salario * 0.2
  else:
    bonus = salario * 0.1
  print(f'Você tem {tempo} anos dentro desta empresa.')
  print(f'Seu salário é de {salario}.')
  print(f'E sua bonificação é de {bonus}.')
  print(f'Salário final: {bonus + salario}.')
# Out:
# Qual seu salário? 2000
# Qual seu ano de admissão na empresa? 2020
# Em que ano estamos? 2025
# Você tem 5 anos dentro desta empresa.
# Seu salário é de 2000.0.
# E sua bonificação é de 200.0.
# Salário final: 2200.0.

# %%
# Exercício 4.1.1
print('Escolha o que deseja comprar:')
print('1 - Maça')
print('2 - Laranja')
print('3 - Banana')
produto = int(input('Qual sua escolha? '))
qtd = int(input('Quantas unidade? '))
if (produto == 1): #maça
  pagar = qtd * 2.3
  print(f'Você comprou {qtd} maças. Total à pagar: {pagar}')
else:
 if (produto == 2): #laranja
  pagar = qtd * 3.6
  print(f'Você comprou {qtd} laranjas. Total à pagar: {pagar}')
 else:
  if (produto == 3): #Banana
    pagar = qtd * 1.85
    print(f'Você comprou {qtd} bananas. Total à pagar: {pagar}')
  else:
    print('Produto inexistente!')
# Out:
# Escolha o que deseja comprar:
# 1 - Maça
# 2 - Laranja
# 3 - Banana
# Qual sua escolha? 2
# Quantas unidade? 3
# Você comprou 3 laranjas. Total à pagar: 10.8

# %%
# Exercício 4.1.2
A = int(input('Digite o 1º lado do triângulo: '))
B = int(input('Digite o 2º lado do triângulo: '))
C = int(input('Digite o 3º lado do triângulo: '))

if A > 0 and B > 0 and C > 0:
  if A + B > C and A + C > B and B + C > A:
    #Se chegou até aqui, é porque o triângulo é válido
    if A != B and A != C and B != C:
      print('Triângulo escaleno.')
    else:
       if A == B and A == C and B == C:
          print('Triângulo equilátero.')
       else:
            print('Triângulo isósceles.')
  else:
    print('Ao menos um dos valores indicados não servem para formar um triângulo.')
else:
     print('Ao menos um dos valores indicados não servem para formar um triângulo.')
# Out:
# Digite o 1º lado do triângulo: 0
# Digite o 2º lado do triângulo: 0
# Digite o 3º lado do triângulo: 0
# Ao menos um dos valores indicados não servem para formar um triângulo.

# %% [markdown]
# **TEMA 5 - CONDICIONAIS DE MÚLTIPLA ESCOLHA (elif)**

# %%
# Exercício 4.1.1 com elif
print('Escolha o que deseja comprar:')
print('1 - Maça')
print('2 - Laranja')
print('3 - Banana')
produto = int(input('Qual sua escolha? '))
qtd = int(input('Quantas unidade? '))

if (produto == 1): #maça
  pagar = qtd * 2.3
  print(f'Você comprou {qtd} maças. Total à pagar: {pagar}')
elif (produto == 2): #laranja
  pagar = qtd * 3.6
  print(f'Você comprou {qtd} laranjas. Total à pagar: {pagar}')
elif (produto == 3): #Banana
    pagar = qtd * 1.85
    print(f'Você comprou {qtd} bananas. Total à pagar: {pagar}')
else:
    print('Produto inexistente!')
# Out:
# Escolha o que deseja comprar:
# 1 - Maça
# 2 - Laranja
# 3 - Banana
# Qual sua escolha? 3
# Quantas unidade? 5
# Você comprou 5 bananas. Total à pagar: 9.25

# %%
#Versão do professor
nome = input('Qual seu nome? ')
idade = int(input('Qual sua idade? '))

if nome == 'Vinicius':
  print('Olá, Vinicius')
elif idade < 18:
  print('Você não é o Vinicius! E é menor de idade! ')
elif idade > 100:
  print('Diferente de você, o Vinicius não é imortal!')
# Out:
# Qual seu nome? Vinicius
# Qual sua idade? 56
# Olá, Vinicius

# %%
#Versão minha
nome = input('Qual seu nome? ')
idade = int(input('Qual sua idade? '))

if nome == 'Ramom Siqueira':
  print('Olá, Ramom Siqueira')
elif idade < 18:
  print('Você não é o Ramom! E é menor de idade! ')
elif idade > 100:
  print('Diferente de você, o Ramom não é imortal!')
# Out:
# Qual seu nome? Ramom Siqueira
# Qual sua idade? 26
# Olá, Ramom Siqueira

# %% [markdown]
# **Exercícios**

# %%
#Exercício 5.1.1

print('CALCULADORA')
print('+ Adição')
print('- Subtração')
print('* Multiplicação')
print('/ Divisão')
print('Digite outra tecla para sair.')

op = input('Qual operação deseja realizar? ')
x = int(input('Digite o primeiro valor: '))
y = int(input('Digite o segundo valor: '))

if (op == '+'):
  res = x + y
  print(f'Resultado: {x} + {y} = {res}')
elif (op == '-'):
  res = x - y
  print(f'Resultado: {x} - {y} = {res}')
elif (op == '*'):
  res = x * y
  print(f'Resultado: {x} * {y} = {res}')
elif (op == '/'):
  res = x / y
  print(f'Resultado: {x} / {y} = {res}')
else:
  print('Operação Inválida!')
# Out:
# CALCULADORA
# + Adição
# - Subtração
# * Multiplicação
# / Divisão
# Digite outra tecla para sair.
# Qual operação deseja realizar?+
# Digite o primeiro valor: 5
# Digite o segundo valor: 5
# Resultado: 5 + 5 = 10

# %%
#Exercício 5.1.2

print('PAGAMENTO')
print('1 - à vista')
print('2 - parcelamento em 3x')
print('3 - parcelamento em 5x')
print('4 - parcelamento em 10x')
print('pressione outra para sair...')

op = int(input('Qual forma de pagamento deseja fazer? '))
valor = float(input('Qual o preço do produto?'))

if (op == 1):
  valor_final = valor * 0.95
  print(f'Produto comprado à vista. Total a pagar: {valor_final}')

elif (op == 2):
  valor_final = valor
  parcela = valor_final / 3
  print(f'Produto parcelado em 3x. Total a pagar: {valor_final}. Valor da parcela: {parcela:.2f}.')
elif (op == 3):
  valor_final = valor * 1.02
  parcela = valor_final / 5
  print(f'Produto parcelado em 5x. Total a pagar: {valor_final}. Valor da parcela: {parcela:.2f}.')
elif (op == 4):
  valor_final = valor * 1.08
  parcela = valor_final / 10
  print(f'Produto parcelado em 10x. Total a pagar: {valor_final}. Valor da parcela: {parcela:.2f}.')
else:
  print('Opção inválida.')
# Out:
# PAGAMENTO
# 1 - à vista
# 2 - parcelamento em 3x
# 3 - parcelamento em 5x
# 4 - parcelamento em 10x
# pressione outra para sair...
# Qual forma de pagamento deseja fazer? 2
# Qual o preço do produto?5
# Produto parcelado em 3x. Total a pagar: 5.0. Valor da parcela: 1.67.
